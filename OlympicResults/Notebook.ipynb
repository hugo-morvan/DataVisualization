# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as md
import dateutil
import time
df = pd.read_csv('C://Users//hugom//OneDrive//Documents//School//Fall21//CSC-457//FinalProject//results.csv')
df.head(5)
# Out:
#   Gender       Event Location    Year Medal                   Name  \
# 0      M  10000M Men      Rio  2016.0     G          Mohamed FARAH
# 1      M  10000M Men      Rio  2016.0     S  Paul Kipngetich TANUI
# 2      M  10000M Men      Rio  2016.0     B           Tamirat TOLA
# 3      M  10000M Men  Beijing  2008.0     G        Kenenisa BEKELE
# 4      M  10000M Men  Beijing  2008.0     S         Sileshi SIHINE
#
#   Nationality    Result  Wind
# 0         USA  25:05.17   NaN
# 1         KEN  27:05.64   NaN
# 2         ETH  27:06.26   NaN
# 3         ETH  27:01.17   NaN
# 4         ETH  27:02.77   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2394 entries, 0 to 2393
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender       2394 non-null   object
#  1   Event        2393 non-null   object
#  2   Location     2393 non-null   object
#  3   Year         2393 non-null   float64
#  4   Medal        2393 non-null   object
#  5   Name         2163 non-null   object
#  6   Nationality  2393 non-null   object
#  7   Result       2393 non-null   object
#  8   Wind         10 non-null     float64
# dtypes: float64(2), object(7)
# memory usage: 168.5+ KB

# %%
df.describe()
#Not very relevant, only two numeric fields
#Although interesting for the wind. Show that the wind has only been recorded 10 times, and all of the winds were legal 
# i.e. respect the rules set by world athletics of within +/- 2.0 m/s wind
# Out:
#               Year       Wind
# count  2393.000000  10.000000
# mean   1970.396991  -0.050000
# std      34.708213   0.625833
# min    1896.000000  -0.900000
# 25%    1948.000000  -0.650000
# 50%    1976.000000   0.100000
# 75%    2000.000000   0.475000
# max    2016.000000   0.600000

# %%
bar_plot = df['Medal'].value_counts().plot(kind='bar', figsize = (14,6))
bar_plot.set_ylabel('Number of medals')
# Out:
# Text(0, 0.5, 'Number of medals')

# %%
#This data was import from kaggle :
# https://www.kaggle.com/jayrav13/olympic-track-field-results
#it represents the podium results from Track and field events in the different Olympic games through history.

# %%
df.groupby(['Event']).count().sort_values('Result', ascending = False)
#This command shows the Event with the most data values
# Out:
#                           Gender  Location  Year  Medal  Name  Nationality  \
# Event
# Marathon Men                  84        84    84     84    84           84
# 100M Men                      82        82    82     82    82           82
# 1500M Men                     81        81    81     81    81           81
# 800M Men                      81        81    81     81    81           81
# 110M Hurdles Men              80        80    80     80    80           80
# 400M Men                      80        80    80     80    80           80
# 200M Men                      78        78    78     78    78           78
# Decathlon Men                 76        76    76     76    76           76
# 400M Hurdles Men              75        75    75     75    75           75
# 3000M Steeplechase Men        72        72    72     72    72           72
# 4X400M Relay Men              71        71    71     71     0           71
# ...

# %%
df.groupby(['Year']).count().sort_values('Result', ascending = False)
#This command show the Year with the most data values
#The fact that wde have more data for the most recent years comes from the fact that the most recent years are more documented
#But could also be because more events were added over the years.

#Notice that the year 1988 has very few data -> exclude in analysis ?
# Out:
#         Gender  Event  Location  Medal  Name  Nationality  Result  Wind
# Year
# 2016.0     141    141       141    141   129          141     141     0
# 2000.0     140    140       140    140   128          140     140     0
# 2012.0     138    138       138    138   126          138     138     0
# 2004.0     136    136       136    136   124          136     136     0
# 1996.0     130    130       130    130   118          130     130     0
# 2008.0     128    128       128    128   119          128     128    10
# 1992.0     125    125       125    125   113          125     125     0
# 1980.0     111    111       111    111    99          111     111     0
# 1964.0     102    102       102    102    93          102     102     0
# 1960.0      99     99        99     99    90           99      99     0
# 1984.0      97     97        97     97    85           97      97     0
# 1976.0      96     96        96     96    84           96      96     0
# ...

# %%
#from this initial pre-analysis of the data, I have decided to analyse the evolution of winning performances at the Olympics
#over time
#I will start with the 100m

# %%
sprint_df = df.loc[df['Event'] == '100M Men']
sprint_df.sort_values(by=['Year'])
sprint_df = sprint_df.reset_index(drop = True)
sprint_df.head(5)
# Out:
#   Gender     Event Location    Year Medal              Name Nationality  \
# 0      M  100M Men      Rio  2016.0     G        Usain BOLT         JAM
# 1      M  100M Men      Rio  2016.0     S     Justin GATLIN         USA
# 2      M  100M Men      Rio  2016.0     B   Andre DE GRASSE         CAN
# 3      M  100M Men  Beijing  2008.0     G        Usain BOLT         JAM
# 4      M  100M Men  Beijing  2008.0     S  Richard THOMPSON         TTO
#
#   Result  Wind
# 0   9.81   NaN
# 1   9.89   NaN
# 2   9.91   NaN
# 3   9.69   NaN
# 4   9.89   NaN

# %%
YR_df = sprint_df.drop(columns=['Gender']+['Location']+['Event']+['Medal']+['Name']+['Nationality']+['Wind'])
YR_df.sort_values('Year',inplace = True, ascending = False)
year = YR_df['Year'].to_list()
result = YR_df['Result'].to_list()
print(year)
print(result)
plt.plot(year,result,'o')
plt.show()
# Out:
# [2016.0, 2016.0, 2016.0, 2012.0, 2012.0, 2012.0, 2008.0, 2008.0, 2008.0, 2004.0, 2004.0, 2004.0, 2000.0, 2000.0, 2000.0, 1996.0, 1996.0, 1996.0, 1992.0, 1992.0, 1992.0, 1984.0, 1984.0, 1984.0, 1980.0, 1980.0, 1980.0, 1976.0, 1976.0, 1976.0, 1972.0, 1972.0, 1972.0, 1968.0, 1968.0, 1968.0, 1964.0, 1964.0, 1964.0, 1960.0, 1960.0, 1960.0, 1956.0, 1956.0, 1956.0, 1952.0, 1952.0, 1952.0, 1948.0, 1948.0, 1948.0, 1936.0, 1936.0, 1936.0, 1932.0, 1932.0, 1932.0, 1928.0, 1928.0, 1928.0, 1924.0, 1924.0, 1924.0, 1920.0, 1920.0, 1920.0, 1912.0, 1912.0, 1912.0, 1908.0, 1908.0, 1908.0, 1904.0, 1904.0, 1904.0, 1900.0, 1900.0, 1900.0, 1896.0, 1896.0, 1896.0, 1896.0]
# ...

# %%
YR_df = sprint_df.drop(columns=['Gender']+['Location']+['Event']+['Medal']+['Name']+['Nationality']+['Wind'])
YR_df.sort_values('Year',inplace = True, ascending = False)
YR_df = YR_df.loc[df['Medal'] == 'G']

year = YR_df['Year'].to_list()
result = YR_df['Result'].to_list()
print(year)
print(result)
plt.plot(year,result, )
plt.show()
# Out:
# [2016.0, 2012.0, 2008.0, 2004.0, 2000.0, 1996.0, 1992.0, 1984.0, 1980.0, 1976.0, 1972.0, 1968.0, 1964.0, 1960.0, 1956.0, 1952.0, 1948.0, 1936.0, 1932.0, 1928.0, 1924.0, 1920.0, 1912.0, 1908.0, 1904.0, 1900.0, 1896.0, 1896.0]
# ['9.81', '9.63', '9.69', '9.85', '9.87', '9.84', '9.96', '9.99', '10.25', '10.06', '10.14', '9.9', '10.0', '10.2', '10.5', '10.4', '10.3', '10.3', '10.3', '10.8', '10.6', '10.8', '10.8', '10.8', '11.0', '11.0', '12.0', '12.6']

# %%
#Only the gold medals
YR_df = sprint_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])
YR_df.sort_values('Year',inplace = True, ascending = False)
YR_df = YR_df.loc[df['Medal'] == 'G']
YR_df.sort_values('Year')

year = np.array(YR_df['Year'].to_list()).astype(float)
result = np.array(YR_df['Result'].to_list()).astype(float)
#print(result)
#print(year)
plt.scatter(year,result, c="gold")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1716/1008011645.py in <module>
#       6
#       7 year = np.array(YR_df['Year'].to_list()).astype(float)
# ----> 8 result = np.array(YR_df['Result'].to_list(), dtype='datetime64[s]').astype(float)
#       9 #print(result)
#      10 #print(year)
#
# ValueError: Error parsing datetime string "9.81" at position 1

# %%
YR_df = sprint_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])
YR_df.sort_values('Year',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']

year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="brown")
year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gray")
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gold")


font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 100m podium times in History", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("100m time (s)")
plt.show()

# %%
hurdles_df = df.loc[df['Event'] == '110M Hurdles Men']
YR_df = hurdles_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])
YR_df.sort_values('Year',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']

year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="brown")

year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gray")


year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gold")

plt.scatter(2020,13.76, c="green")

font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 110mH podium times in History (And me in green)", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("110mH time (s)")


plt.show()

# %%
quarter_df = df.loc[df['Event'] == '400M Men']
YR_df = quarter_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])
YR_df.sort_values('Result',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']


year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="brown")

year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gray")


year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gold")

font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 400m podium times in History", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("400m time (s)")
plt.show()

# %%
quarter_df = df.loc[df['Event'] == '200M Men']
YR_df = quarter_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])
YR_df.sort_values('Result',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']


year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="brown")

year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gray")


year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gold")

font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 200m podium times in History", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("200m time (s)")
plt.show()

# %%
quarter_df = df.loc[df['Event'] == '800M Men']
YR_df = quarter_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])
YR_df.sort_values('Result',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']


year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list(), dtype='datetime64[ms]')
plt.scatter(year,result, c="brown")

year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list(), dtype='datetime64[ms]') 
plt.scatter(year,result, c="gray")


year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list(), dtype='datetime64[ms]') 
plt.scatter(year,result, c="gold")

font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 800m podium times in History", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("800m time (s)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1716/2771949650.py in <module>
#       9
#      10 year = np.array(YRB_df['Year'].to_list()).astype(float)
# ---> 11 result = np.array(YRB_df['Result'].to_list(), dtype='datetime64[s]')
#      12 plt.scatter(year,result, c="brown")
#      13
#
# ValueError: Error parsing datetime string "None" at position 0

# %%
YR_df = sprint_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])

YR_df.sort_values('Year',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']

year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="brown")
year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gray")
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

plt.scatter(year,result, c="gold")

font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 100m podium times in History", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("100m time (s)")

###
#Polynomial trend
###
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

coeff = np.polyfit(year,result,1)

Year_trend = np.linspace(year[0],year[-1],120)
result_trend = np.polyval(coeff,Year_trend)

plt.plot(Year_trend,result_trend,'r-')
print(coeff[0]*2021+coeff[1])
# Out:
# 9.431784425950156

# %%
YR_df = sprint_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])


YR_df.sort_values('Year',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']

year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="brown")
year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gray")
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

plt.scatter(year,result, c="gold")


font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 100m podium times in History", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("100m time (s)")

###
#Polynomial trend (2nd order)
###
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

coeff = np.polyfit(year,result,2)

Year_trend = np.linspace(year[0],year[-1],100)
result_trend = np.polyval(coeff,Year_trend)

plt.plot(Year_trend,result_trend,'r-')

#from this calculate the result for the year 2021
print("Predicted time for 2021 gold medal is ")
print(coeff[0]*2021*2021+coeff[1]*2021+coeff[2])
# Out:
# Predicted time for 2021 gold medal is
# 9.89588858089769

# %%
YR_df = sprint_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])


YR_df.sort_values('Year',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']

year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="brown")
year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gray")
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

plt.scatter(year,result, c="gold")


font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 100m podium times in History", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("100m time (s)")

###
#Polynomial trend (3nd order)
###
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

coeff = np.polyfit(year,result,3)

Year_trend = np.linspace(year[0],year[-1],100)
result_trend = np.polyval(coeff,Year_trend)

plt.plot(Year_trend,result_trend,'r-')

#from this calculate the result for the year 2021
print(coeff)
print("Predicted time for 2021 gold medal is ")
print(coeff[0]*2021*2021*2021+coeff[1]*2021*2021+coeff[2]*2021+coeff[3])
# Out:
# [-4.07030227e-06  2.40293598e-02 -4.72888350e+01  3.10325700e+04]
# Predicted time for 2021 gold medal is
# 9.394815799791104

# %%
YR_df = sprint_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])


YR_df.sort_values('Year',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']

year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="brown")
year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gray")
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

plt.scatter(year,result, c="gold")


font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 100m podium times in History", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("100m time (s)")

###
#Polynomial trend (4th order)
###
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

coeff = np.polyfit(year,result,4)

Year_trend = np.linspace(year[0],year[-1],100)
result_trend = np.polyval(coeff,Year_trend)

plt.plot(Year_trend,result_trend,'r-')

#from this calculate the result for the year 2021
print(coeff)
print("Predicted time for 2021 gold medal is ")
print(coeff[0]*2021*2021*2021*2021+coeff[1]*2021*2021*2021+coeff[2]*2021*2021+coeff[3]*2021+coeff[4])
# Out:
# [ 9.76512628e-08 -7.67672958e-04  2.26287139e+00 -2.96425987e+03
#   1.45600741e+06]
# Predicted time for 2021 gold medal is
# 9.92735450528562

# %%
YR_df = sprint_df.drop(columns=['Gender']+['Location']+['Event']+['Name']+['Nationality']+['Wind'])


YR_df.sort_values('Year',inplace = True, ascending = False)
YRG_df = YR_df.loc[df['Medal'] == 'G']
YRS_df = YR_df.loc[df['Medal'] == 'S']
YRB_df = YR_df.loc[df['Medal'] == 'B']

year = np.array(YRB_df['Year'].to_list()).astype(float)
result = np.array(YRB_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="brown")
year = np.array(YRS_df['Year'].to_list()).astype(float)
result = np.array(YRS_df['Result'].to_list()).astype(float)
plt.scatter(year,result, c="gray")
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

plt.scatter(year,result, c="gold")


font1={'family':'serif', 'color':'black', 'size':15}
plt.title("Evolution of 100m podium times in History", fontdict=font1)
plt.xlabel("Year")
plt.ylabel("100m time (s)")

###
#logarithmic trend
###
year = np.array(YRG_df['Year'].to_list()).astype(float)
result = np.array(YRG_df['Result'].to_list()).astype(float)

fit = np.polyfit(np.log(year),result,1)

print(fit)
print("predicted time")
print(fit[0]*np.log(2021)+fit[1])
# Out:
# [-29.00435745 230.20268825]
# predicted time
# 9.440438382121954
